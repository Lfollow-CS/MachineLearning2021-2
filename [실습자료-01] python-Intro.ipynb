# %% [markdown]
# ##학습자료
# - [점프투파이썬](https://wikidocs.net/book/1)
# - [데이터사이언스스쿨](https://datascienceschool.net/intro.html)

# %% [markdown]
# ##파이썬이란
# ![Python](https://www.python.org/static/img/python-logo.png)

# %% [markdown]
# - 1990년 Guido Van Rossum에 의해 개발된 언어
# - Interpreter 언어 ( 한 줄씩 소스 코드를 해석해서 그때그때 실행해 결과를 바로 확인할 수 있는 언어)

# %% [markdown]
# ###장점
# - 문법이 간단해서 배우기 쉽다.
# - 많은 개발자들이 사용하고 있다.
# - 다양한 패키지가 배포되고 있다.

# %% [markdown]
# ###단점
# - C언어에 비해 느리다.
# - 패키지 버전관리가 필요하다.

# %% [markdown]
# ##파이썬 실행하기
# - 설치없이 실행하기
# - 설치 후 console에서 실행하기
# - editor로 편집하여 .py파일로 저장 후 실행하기
# - 통합개발환경 (IDE)에서 실행하기
# - Jupyter notebook으로 실행하기
# - Google Colab에서 실행하기

# %% [markdown]
# ##파이썬 설치하지 않고 파이썬 실행하기
# <https://hashcode.co.kr/code_runners?language=python3>
#
# <http://www.codeskulptor.org/>
#
# <https://ideone.com/>

# %% [markdown]
# ##Install Python
# [공식 홈페이지 다운받아 설치하기](https://wikidocs.net/8)
#
# [anaconda 설치](https://wikidocs.net/2825)

# %% [markdown]
# ##Jupyter Notebook

# %% [markdown]
# ##Markdown
# [Guide](https://colab.research.google.com/notebooks/markdown_guide.ipynb)

# %% [markdown]
# ##Google Colaboratory
# = Google Drive + Jupyter Notebook
#
# [Intrudiction: Google Colab](https://colab.research.google.com/drive/0B2Op0f7i-jUEem1NUWVaRDlwVVE#scrollTo=PYUoUDZlPvsN)
#
# [Welcome to Google Colab](https://colab.research.google.com/notebooks/welcome.ipynb#scrollTo=nGXrezT31pvC)
